# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("D:\\DataSets\\compresive_strength_concrete.xls",
                 names=['Cement','Blast Furnace slag','Fly Ash','Water','Superplasticizer','Coarse Aggregate',
                         'Fine Aggregate','Age','Concrete compressive strength'],header=0)
df.head()
# Out:
#    Cement  Blast Furnace slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Concrete compressive strength
# 0            1040.0           676.0   28                          79.99
# 1            1055.0           676.0   28                          61.89
# 2             932.0           594.0  270                          40.27
# 3             932.0           594.0  365                          41.05
# 4             978.4           825.5  360                          44.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# Cement                           1030 non-null float64
# Blast Furnace slag               1030 non-null float64
# Fly Ash                          1030 non-null float64
# Water                            1030 non-null float64
# Superplasticizer                 1030 non-null float64
# Coarse Aggregate                 1030 non-null float64
# Fine Aggregate                   1030 non-null float64
# Age                              1030 non-null int64
# Concrete compressive strength    1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.isnull().sum()
# Out:
# Cement                           0
# Blast Furnace slag               0
# Fly Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse Aggregate                 0
# Fine Aggregate                   0
# Age                              0
# Concrete compressive strength    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Cement                           0
# Blast Furnace slag               0
# Fly Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse Aggregate                 0
# Fine Aggregate                   0
# Age                              0
# Concrete compressive strength    0
# dtype: int64

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.describe().T
# Out:
#                                 count        mean         std     min  \
# Cement                         1030.0  281.167864  104.506364  102.00
# Blast Furnace slag             1030.0   73.895825   86.279342    0.00
# Fly Ash                        1030.0   54.188350   63.997004    0.00
# Water                          1030.0  181.567282   21.354219  121.80
# Superplasticizer               1030.0    6.204660    5.973841    0.00
# Coarse Aggregate               1030.0  972.918932   77.753954  801.00
# Fine Aggregate                 1030.0  773.580485   80.175980  594.00
# Age                            1030.0   45.662136   63.169912    1.00
# Concrete compressive strength  1030.0   35.817961   16.705742    2.33
#
#                                    25%      50%       75%     max
# Cement                         192.375  272.900   350.000   540.0
# Blast Furnace slag               0.000   22.000   142.950   359.4
# Fly Ash                          0.000    0.000   118.300   200.1
# ...

# %%
df.columns
# Out:
# Index(['Cement', 'Blast Furnace slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age',
#        'Concrete compressive strength'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis of each Attribute

# %%
sns.distplot(df['Cement'])

# %%
df['Cement'].describe()
# Out:
# count    1030.000000
# mean      281.167864
# std       104.506364
# min       102.000000
# 25%       192.375000
# 50%       272.900000
# 75%       350.000000
# max       540.000000
# Name: Cement, dtype: float64

# %% [raw]
# From the above Cement attribute we can infer that data is rights skewed and normally ditributed and max value is not for away from median value and cement strength ranges between 200 to 500.

# %%
sns.distplot(df['Blast Furnace slag'])

# %%
df['Blast Furnace slag'].describe()
# Out:
# count    1030.000000
# mean       73.895825
# std        86.279342
# min         0.000000
# 25%         0.000000
# 50%        22.000000
# 75%       142.950000
# max       359.400000
# Name: Blast Furnace slag, dtype: float64

# %% [raw]
# From the above Blast Furnace slag attribute we can infer that data is rights skewed and not normally ditributed and max value is for away from median value and there is outliers in the attribute.

# %%
sns.distplot(df['Fly Ash'])

# %%
df['Fly Ash'].describe()
# Out:
# count    1030.000000
# mean       54.188350
# std        63.997004
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       118.300000
# max       200.100000
# Name: Fly Ash, dtype: float64

# %% [raw]
# We can infer that the data is rights skewed and thers is peak at 0th value so that there 0 fly ash and there is outlier in the attribute.

# %%
sns.distplot(df['Water'])

# %%
df['Water'].describe()
# Out:
# count    1030.000000
# mean      181.567282
# std        21.354219
# min       121.800000
# 25%       164.900000
# 50%       185.000000
# 75%       192.000000
# max       247.000000
# Name: Water, dtype: float64

# %% [raw]
# We can infer that water is normally distributed and slightly rights skewed and there is not much outlier in the attribute.

# %%
sns.distplot(df['Superplasticizer'])

# %%
df['Superplasticizer'].describe()
# Out:
# count    1030.000000
# mean        6.204660
# std         5.973841
# min         0.000000
# 25%         0.000000
# 50%         6.400000
# 75%        10.200000
# max        32.200000
# Name: Superplasticizer, dtype: float64

# %% [raw]
# Data is not normal and slightly lefts skewed and there is an outlier in the attribure and max value is far away from median value.

# %%
sns.distplot(df['Coarse Aggregate'])

# %%
df['Coarse Aggregate'].describe()
# Out:
# count    1030.000000
# mean      972.918932
# std        77.753954
# min       801.000000
# 25%       932.000000
# 50%       968.000000
# 75%      1029.400000
# max      1145.000000
# Name: Coarse Aggregate, dtype: float64

# %% [raw]
# We can infer that data is normal and it is rights skewed and not having outliers.

# %%
sns.distplot(df['Fine Aggregate'])

# %%
df['Fine Aggregate'].describe()
# Out:
# count    1030.000000
# mean      773.580485
# std        80.175980
# min       594.000000
# 25%       730.950000
# 50%       779.500000
# 75%       824.000000
# max       992.600000
# Name: Fine Aggregate, dtype: float64

# %% [raw]
# We can infer that data is normal and it is rights skewed and not having outliers.

# %%
sns.distplot(df['Age'])

# %%
df['Age'].describe()
# Out:
# count    1030.000000
# mean       45.662136
# std        63.169912
# min         1.000000
# 25%         7.000000
# 50%        28.000000
# 75%        56.000000
# max       365.000000
# Name: Age, dtype: float64

# %% [raw]
# We can infer that data is rights skewed and its not normally distributed and there is an outliers in the age of concrete.

# %%
sns.distplot(df['Concrete compressive strength'])

# %%
df['Concrete compressive strength'].describe()
# Out:
# count    1030.000000
# mean       35.817961
# std        16.705742
# min         2.330000
# 25%        23.710000
# 50%        34.445000
# 75%        46.135000
# max        82.600000
# Name: Concrete compressive strength, dtype: float64

# %% [raw]
# We can infer that compressive strength is normally distributed and slightly rights skewed and there is an outliers in the attribute.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,diag_kind='kde')

# %%
corr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [raw]
# We can infer that there is less multi-collinearity between attributes and correlation is more between cement,superplasticizer,Age and concrete strength.

# %% [markdown]
# # Building the model

# %%
from sklearn.model_selection import train_test_split

y = df['Concrete compressive strength']
X = df.drop(['Concrete compressive strength'],axis=1)

X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3, random_state=42,)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((721, 8), (309, 8), (721,), (309,))

# %%
#Scaling the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = pd.DataFrame(scaler.transform(X_train),
                              columns = X_train.columns)
X_train_scaled.head()
# Out:
#      Cement  Blast Furnace slag   Fly Ash     Water  Superplasticizer  \
# 0 -0.828484           -0.855296  0.761701 -0.766488          0.227273
# 1  0.374823           -0.855296 -0.816913  0.103748         -1.013995
# 2  0.317566            1.568935 -0.816913 -1.234713          1.352690
# 3  0.688809           -0.638541  1.397859 -1.315115          0.789982
# 4 -1.130465            1.312252  1.507813 -0.132729          2.130551
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.415545        1.676803 -0.292980
# 1          1.136979        0.141904 -0.633845
# 2         -1.551191        1.358333 -0.698772
# 3         -0.405309        0.366706 -0.698772
# 4         -1.730912       -0.382635 -0.292980

# %%
#We will save the model performance metrics in a DataFrame
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold, cross_val_score
import numpy as np
Model = []
RMSE = []
R_sq = []
cv = KFold(5, random_state = 1)

#Creating a Function to append the cross validation scores of the algorithms
def input_scores(name, model, X, y):
    Model.append(name)
    RMSE.append(np.sqrt((-1) * cross_val_score(model, X, y, cv=cv, 
                                               scoring='neg_mean_squared_error').mean()))
    R_sq.append(cross_val_score(model, X, y, cv=cv, scoring='r2').mean())

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (RandomForestRegressor, GradientBoostingRegressor, 
                              AdaBoostRegressor)

names = ['Linear Regression', 'Ridge Regression', 'Lasso Regression',
         'K Neighbors Regressor', 'Decision Tree Regressor', 
         'Random Forest Regressor', 'Gradient Boosting Regressor',
         'Adaboost Regressor']
models = [LinearRegression(), Ridge(), Lasso(),
          KNeighborsRegressor(), DecisionTreeRegressor(),
          RandomForestRegressor(), GradientBoostingRegressor(), 
          AdaBoostRegressor()]

#Running all algorithms
for name, model in zip(names, models):
    input_scores(name, model, X_train_scaled, y_train)

# %%
evaluation = pd.DataFrame({'Model': Model,
                           'RMSE': RMSE,
                           'R Squared': R_sq})
print("FOLLOWING ARE THE TRAINING SCORES: ")
evaluation
# Out:
# FOLLOWING ARE THE TRAINING SCORES:
#                          Model       RMSE  R Squared
# 0            Linear Regression  10.655513   0.596628
# 1             Ridge Regression  10.652831   0.596935
# 2             Lasso Regression  11.116726   0.561457
# 3        K Neighbors Regressor   9.460496   0.675249
# 4      Decision Tree Regressor   7.628691   0.792630
# 5      Random Forest Regressor   5.721806   0.876969
# 6  Gradient Boosting Regressor   5.407991   0.894764
# 7           Adaboost Regressor   7.603020   0.786542

# %% [markdown]
# # Conclusion

# %% [raw]
# From above it can be found that Gradient Boosting Regressor gives 89.94% accuracy with Root Mean Square Error (RMSE) of 5.40.
# We can conclude that all features are predicting the good accuracy for concrete strength in Gradient boost regressor.
